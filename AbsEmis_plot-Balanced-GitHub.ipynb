# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("data/absemis_stats-Balanced.csv", delimiter=';')
data
# Out:
#          Group  Participants      Mean       Std   conf_lo   conf_hi Question
# 0      Experts            17  0.335294  0.260201  0.300149  0.372370    Lines
# 1  Non experts            17  0.113793  0.076331  0.096475  0.133770    Lines
# 2  Astronomers             4  0.325000  0.264837  0.256083  0.402538    Lines
# 3    Musicians            10  0.300000  0.266667  0.256361  0.347615    Lines
# 4     AstroMus             3  0.466667  0.322031  0.378160  0.557351    Lines
# 5         BVI2            17  0.229412  0.139891  0.198819  0.263177    Lines
# 6      Non BVI            29  0.279310  0.198055  0.253762  0.306378    Lines
# 7        Total            46  0.260870  0.169013  0.240930  0.281840    Lines

# %%
data['Group']
# Out:
# 0        Experts
# 1    Non experts
# 2    Astronomers
# 3      Musicians
# 4       AstroMus
# 5           BVI2
# 6        Non BVI
# 7          Total
# Name: Group, dtype: object

# %%
means = data['Mean']
means = np.array(means)
means
# Out:
# array([0.335294, 0.113793, 0.325   , 0.3     , 0.466667, 0.229412,
#        0.27931 , 0.26087 ])

# %%
data['Std'][0]
# Out:
# 0.260201

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.patches import Rectangle

# %%
labels = ['Astronomers','Musicians','Experts','Non experts', 'BVI', 'Non BVI']

fig, ax = plt.subplots(figsize=(14,6),dpi=200)
x = np.arange(len(labels))

bar_width = .9

rects1 = ax.bar(1 - bar_width/2, means[0] , bar_width, yerr=data['Std'][0], 
                label='Experts',align='center',ecolor='black',capsize=10)
rects2 = ax.bar(2 - bar_width/2, means[1] , bar_width, yerr=data['Std'][1], 
                label='Non experts',align='center',ecolor='black',capsize=10)
ax.set_ylabel('Average success rate',size=12)
ax.set_ylabel('Average success rate',size=12)
ax.yaxis.set_minor_locator(AutoMinorLocator())

ax.add_patch(Rectangle((.46, data['conf_lo'][0]), 
                       0.18, data['conf_hi'][0]-data['conf_lo'][0],
                       alpha=0.5,color='black',label="Jeffreys' confidence intervals"))
ax.add_patch(Rectangle((1.46, data['conf_lo'][1]), 
                       0.18, data['conf_hi'][1]-data['conf_lo'][1],
                       alpha=0.5,color='black'))
ax.set_xticks([])
ax.set_xticklabels([])

ax.legend(fontsize=10,loc='upper right')
plt.savefig('JAES24_AbsEmisPlot.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,6),dpi=200)
x = np.arange(len(labels))
bar_width = .9
rects1 = ax.bar(1 - bar_width/2, means[2] , bar_width, yerr=data['Std'][2], 
                label='Astronomers',color='dodgerblue', align='center',ecolor='black',capsize=10)
rects2 = ax.bar(2 - bar_width/2, means[3] , bar_width, yerr=data['Std'][3], 
                label='Musicians', color='steelblue', align='center',ecolor='black',capsize=10)
rects3 = ax.bar(3 - bar_width/2, means[4] , bar_width, yerr=data['Std'][4], 
                label='AstroMus', color = 'deepskyblue', align='center',ecolor='black',capsize=10)
#ax.set_ylabel('Average success rate',size=12)
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.add_patch(Rectangle((.46, data['conf_lo'][2]), 
                       0.18, data['conf_hi'][2]-data['conf_lo'][2],
                       alpha=0.5,color='cyan',label="Jeffreys' confidence intervals"))
ax.add_patch(Rectangle((1.46, data['conf_lo'][3]), 
                       0.18, data['conf_hi'][3]-data['conf_lo'][3],
                       alpha=0.5,color='cyan'))
ax.add_patch(Rectangle((2.46, data['conf_lo'][4]), 
                       0.18, data['conf_hi'][4]-data['conf_lo'][4],
                       alpha=0.5,color='cyan'))
ax.set_xticks([])
ax.set_xticklabels([])
ax.legend(fontsize=10,loc='upper left')
plt.savefig('JAES24_AbsEmisPlot2.png')
plt.show()
