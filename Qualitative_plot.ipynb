# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/data_plotting.csv", delimiter=';')
data
# Out:
#             Start time       Groups  Qualifications  Q30_2  Q38   Q39   Q40  \
# 0     12/8/22 11:29:21  Non experts             7.5   10.0  7.0   9.0   6.0
# 1    12/11/22 16:39:30  Non experts             7.5    7.5  7.0   9.0   7.0
# 2    12/11/22 18:13:31  Non experts             5.0   10.0  7.0  10.0  10.0
# 3    12/11/22 18:28:52  Non experts             7.5    5.0  3.0   6.0   7.0
# 4    12/11/22 18:36:17  Non experts             5.0    5.0  3.0   8.0   7.0
# ..                 ...          ...             ...    ...  ...   ...   ...
# 455   1/19/23 23:18:21  Astronomers             6.0   10.0  6.0   8.0   3.0
# 456   1/22/23 23:24:03    Musicians             7.0    7.5  6.0   5.0   8.0
# 457  12/15/22 21:19:13      Experts            10.0    5.0  7.0   8.0   3.0
# 458   1/18/23 17:01:54    Musicians             8.0    5.0  6.0   8.0   7.0
# 459   1/18/23 17:38:19    Musicians             7.0    7.5  2.0   5.0   5.0
#
#       Q41   Q42   Q43   Q44   Q45 Questions
# 0     8.0  10.0   9.0   9.0  10.0     Q30_1
# 1     8.0   9.0   9.0   9.0   9.0     Q30_1
# 2    10.0  10.0  10.0  10.0  10.0     Q30_1
# 3     5.0   6.0   5.0   5.0   5.0     Q30_1
# 4     7.0   8.0   6.0   7.0   3.0     Q30_1
# ..    ...   ...   ...   ...   ...       ...
# 455   9.0  10.0   5.0   4.0   NaN       Q45
# 456   8.0   8.0   8.0   6.0   NaN       Q45
# 457   7.0   6.0   7.0   8.0   NaN       Q45
# 458   7.0   9.0   8.0   5.0   NaN       Q45
# 459   6.0   7.0   5.0   7.0   NaN       Q45
#
# [460 rows x 13 columns]

# %%
total_responses = len(data)
print("Number of participants:", total_responses)
# Out:
# Number of participants: 460

# %% [markdown]
# ## Qualitative answers

# %%
#plot = sns.catplot(data=data, x="Question", y="Qualifications", hue="Group", kind="box")
#with sns.color_palette("bright"):
plot = sns.catplot(
    data=data, x="Questions", y="Qualifications", col="Groups", 
    kind="box", height=8, aspect=.6, col_order=["Experts","Astronomers", "Musicians", "Non experts"],
)
#sns.color_palette("Spectral", as_cmap=True)
sns.set_palette('Spectral')
plot.set(xlabel ="", ylabel = "")
plot.set_titles("{col_name}")

#plot2 = sns.swarmplot(data=data, x="Question", y="Qualifications", size=3)


plt.savefig("Qualitative_analysis.png")

# %%
qualifications = data["Qualifications"]
qualifications = np.array(qualifications)

# %%
average = np.mean(qualifications)
median = np.median(qualifications)
print("Average qualification:", average)
print("Median of the qualifications:", median)
# Out:
# Average qualification: 6.415217391304348
# Median of the qualifications: 7.0
