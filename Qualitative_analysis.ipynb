# %%
import pandas as pd
import numpy as np

# %matplotlib inline

import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

style.use('ggplot') or plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm

# %%
data = pd.read_csv("data/data_edited.csv", delimiter=';')
data
# Out:
#            Start time    Completion time      Email            Q1  \
# 0                 NaN                NaN    RESULTS  Sonification
# 1    12/8/22 11:29:21   12/8/22 12:11:53  anonymous  Sonification
# 2   12/11/22 16:39:30  12/11/22 17:06:42  anonymous  Sonification
# 3   12/11/22 18:13:31  12/11/22 18:30:53  anonymous  Sonification
# 4   12/11/22 18:28:52  12/11/22 18:44:49  anonymous  Sonification
# 5   12/11/22 18:36:17  12/11/22 19:10:36  anonymous         Music
# 6   12/11/22 18:29:03  12/11/22 19:50:22  anonymous  Sonification
# 7   12/11/22 21:15:40  12/11/22 21:47:19  anonymous         Music
# 8   12/11/22 21:11:36  12/11/22 21:57:40  anonymous         Music
# 9   12/11/22 21:49:45  12/11/22 23:08:49  anonymous         Music
# 10  12/12/22 10:19:49  12/12/22 10:32:16  anonymous  Sonification
# 11  12/12/22 15:59:40  12/12/22 16:34:36  anonymous         Music
# 12  12/12/22 17:10:04  12/12/22 17:33:43  anonymous  Sonification
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 49 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Start time       45 non-null     object
#  1   Completion time  45 non-null     object
#  2   Email            46 non-null     object
#  3   Q1               46 non-null     object
#  4   Q2               46 non-null     object
#  5   Q3               46 non-null     object
#  6   Q4               46 non-null     object
#  7   Q5               46 non-null     object
#  8   Q6               46 non-null     object
#  9   Q7               46 non-null     object
#  10  Q8               46 non-null     object
#  11  Q9               46 non-null     object
#  12  Q10              46 non-null     object
#  13  Q11              46 non-null     object
#  14  Q12              46 non-null     object
#  15  Q13              46 non-null     object
#  16  Q14              46 non-null     object
# ...

# %% [markdown]
# ## Astronomers

# %%
astro_list = []
astro_index = []
astro_counter = 0
for j in range(len(data)):
    if ((data.Q21[j] == "Astronomer") and (data.Q31[j] != "Musician")):
        astro_counter += 1
        current_row = data.iloc[j]
        astro_list.append(current_row)
        astro_index.append(j)
        
print("Number of Astronomers:", astro_counter)
astro_df = pd.DataFrame(astro_list)
astro_df
# Out:
# Number of Astronomers: 4
#            Start time    Completion time      Email            Q1  \
# 35  12/19/22 17:53:32  12/21/22 17:03:43  anonymous  Sonification
# 36  12/29/22 19:01:02  12/29/22 19:25:38  anonymous         Music
# 38   1/20/23 13:16:03   1/20/23 13:36:43  anonymous         Music
# 42   1/19/23 23:18:21    1/20/23 3:34:54  anonymous         Music
#
#               Q2            Q3            Q4            Q5            Q6  \
# 35  Sonification  Sonification  Sonification  Sonification  Sonification
# 36  Sonification  Sonification  Sonification  Sonification  Sonification
# 38         Music  Sonification  Sonification  Sonification  Sonification
# 42         Music  Sonification  Sonification  Sonification  Sonification
#
#               Q7  ...             Q36     Q37  Q38  Q39  Q40  Q41   Q42  Q43  \
# 35  Sonification  ...   Entre 45 y 54  España  6.0  8.0  7.0  8.0   6.0  8.0
# 36  Sonification  ...   Entre 35 y 44  España  7.0  7.0  7.0  8.0   8.0  6.0
# ...

# %%
astro_df.info()

# %%
len(astro_df)
# Out:
# 4

# %%
astro_df.Q22[astro_index[0]]

# %%
data.Q22[0]

# %%
astro_index[0]
# Out:
# 35

# %%
Q1A = astro_df.Q39[astro_index[0]]
Q1A
# Out:
# 8.0

# %%
astro_df.Q30_2[astro_index[0]]
# Out:
# 'Buena'

# %% [markdown]
# ## Stats by question

# %%
averageQ38 = astro_df['Q38'].mean()
medianQ38 = astro_df['Q38'].median()
averageQ39 = astro_df['Q39'].mean()
medianQ39 = astro_df['Q39'].median()
averageQ40 = astro_df['Q40'].mean()
medianQ40 = astro_df['Q40'].median()
averageQ41 = astro_df['Q41'].mean()
medianQ41 = astro_df['Q41'].median()
averageQ42 = astro_df['Q42'].mean()
medianQ42 = astro_df['Q42'].median()
averageQ43 = astro_df['Q43'].mean()
medianQ43 = astro_df['Q43'].median()
averageQ44 = astro_df['Q44'].mean()
medianQ44 = astro_df['Q44'].median()
averageQ45 = astro_df['Q45'].mean()
medianQ45 = astro_df['Q45'].median()

print("Q38 mean:",averageQ38)
print("Q38 median:",medianQ38)
print("Q39 mean:",averageQ39)
print("Q39 median:",medianQ39)
print("Q40 mean:",averageQ40)
print("Q40 median:",medianQ40)
print("Q41 mean:",averageQ41)
print("Q41 median:",medianQ41)
print("Q42 mean:",averageQ42)
print("Q42 median:",medianQ42)
print("Q43 mean:",averageQ43)
print("Q43 median:",medianQ43)
print("Q44 mean:",averageQ44)
print("Q44 median:",medianQ44)
print("Q45 mean:",averageQ45)
print("Q45 median:",medianQ45)
# Out:
# Q38 mean: 6.0
# Q38 median: 6.0
# Q39 mean: 6.5
# Q39 median: 7.5
# Q40 mean: 4.75
# Q40 median: 5.0
# Q41 mean: 8.0
# Q41 median: 8.0
# Q42 mean: 7.5
# Q42 median: 7.0
# Q43 mean: 6.0
# Q43 median: 5.5
# Q44 mean: 4.75
# Q44 median: 4.5
# Q45 mean: 5.75
# Q45 median: 6.0

# %% [markdown]
# ## Questions Q30_1 and Q30_2

# %%
Q9A = []
Q10A = []

for i in range(len(astro_df)):
    if astro_df.Q30_1[astro_index[i]] == "Muy buena":
        Q9A.append(10)
    elif astro_df.Q30_1[astro_index[i]] == "Buena":
        Q9A.append(7.5)
    elif astro_df.Q30_1[astro_index[i]] == "Regular":
        Q9A.append(5)
    elif astro_df.Q30_1[astro_index[i]] == "Mala":
        Q9A.append(2.5)
    else:
        Q9A.append(0)
    
    if astro_df.Q30_2[astro_index[i]] == "Muy buena":
        Q10A.append(10)
    elif astro_df.Q30_2[astro_index[i]] == "Buena":
        Q10A.append(7.5)
    elif astro_df.Q30_2[astro_index[i]] == "Regular":
        Q10A.append(5)
    elif astro_df.Q30_2[astro_index[i]] == "Mala":
        Q10A.append(2.5)
    else:
        Q10A.append(0)

# %%
Q9A
# Out:
# [5, 7.5, 2.5, 5]

# %%
Q10A
# Out:
# [7.5, 7.5, 7.5, 10]

# %%
Q9A = np.array(Q9A)
Q10A = np.array(Q10A)
averageQ9A = np.mean(Q9A)
medianQ9A = np.median(Q9A)
averageQ10A = np.mean(Q10A)
medianQ10A = np.median(Q10A)

print("Q30_1 mean:",averageQ9A)
print("Q30_1 median:",medianQ9A)
print("Q30_2 mean:",averageQ10A)
print("Q30_2 median:",medianQ10A)
# Out:
# Q30_1 mean: 5.0
# Q30_1 median: 5.0
# Q30_2 mean: 8.125
# Q30_2 median: 7.5

# %% [markdown]
# ## Musicians

# %%
music_list = []
music_index = []
music_counter = 0
for j in range(len(data)):
    if ((data.Q31[j] == "Musician") and (data.Q21[j] != "Astronomer")):
        music_counter += 1
        current_row = data.iloc[j]
        music_list.append(current_row)
        music_index.append(j)
        
print("Number of Musicians:", music_counter)
music_df = pd.DataFrame(music_list)
music_df
# Out:
# Number of Musicians: 9
#            Start time    Completion time      Email            Q1  \
# 6   12/11/22 18:29:03  12/11/22 19:50:22  anonymous  Sonification
# 7   12/11/22 21:15:40  12/11/22 21:47:19  anonymous         Music
# 26  12/16/22 10:38:46  12/16/22 11:09:38  anonymous         Music
# 27  12/16/22 13:24:21  12/16/22 13:51:45  anonymous         Music
# 30  12/18/22 21:15:43  12/18/22 21:41:39  anonymous  Sonification
# 32  12/19/22 22:28:22  12/19/22 22:50:23  anonymous         Music
# 41   1/19/23 23:16:28    1/20/23 0:15:44  anonymous         Music
# 44   1/18/23 17:01:54   1/18/23 17:30:51  anonymous         Music
# 45   1/18/23 17:38:19   1/18/23 17:56:25  anonymous  Sonification
#
#               Q2            Q3            Q4             Q5            Q6  \
# 6   Sonification  Sonification  Sonification   Sonification  Sonification
# 7          Music         Music  Sonification   Sonification         Music
# ...

# %%
averageQ38 = music_df['Q38'].mean()
medianQ38 = music_df['Q38'].median()
averageQ39 = music_df['Q39'].mean()
medianQ39 = music_df['Q39'].median()
averageQ40 = music_df['Q40'].mean()
medianQ40 = music_df['Q40'].median()
averageQ41 = music_df['Q41'].mean()
medianQ41 = music_df['Q41'].median()
averageQ42 = music_df['Q42'].mean()
medianQ42 = music_df['Q42'].median()
averageQ43 = music_df['Q43'].mean()
medianQ43 = music_df['Q43'].median()
averageQ44 = music_df['Q44'].mean()
medianQ44 = music_df['Q44'].median()
averageQ45 = music_df['Q45'].mean()
medianQ45 = music_df['Q45'].median()

print("Q38 mean:",averageQ38)
print("Q38 median:",medianQ38)
print("Q39 mean:",averageQ39)
print("Q39 median:",medianQ39)
print("Q40 mean:",averageQ40)
print("Q40 median:",medianQ40)
print("Q41 mean:",averageQ41)
print("Q41 median:",medianQ41)
print("Q42 mean:",averageQ42)
print("Q42 median:",medianQ42)
print("Q43 mean:",averageQ43)
print("Q43 median:",medianQ43)
print("Q44 mean:",averageQ44)
print("Q44 median:",medianQ44)
print("Q45 mean:",averageQ45)
print("Q45 median:",medianQ45)
# Out:
# Q38 mean: 4.555555555555555
# Q38 median: 5.0
# Q39 mean: 6.444444444444445
# Q39 median: 7.0
# Q40 mean: 6.0
# Q40 median: 6.0
# Q41 mean: 7.555555555555555
# Q41 median: 7.0
# Q42 mean: 8.0
# Q42 median: 8.0
# Q43 mean: 6.666666666666667
# Q43 median: 7.0
# Q44 mean: 5.666666666666667
# Q44 median: 5.0
# Q45 mean: 6.555555555555555
# Q45 median: 7.0

# %%
Q9A = []
Q10A = []

for i in range(len(music_df)):
    if music_df.Q30_1[music_index[i]] == "Muy buena":
        Q9A.append(10)
    elif music_df.Q30_1[music_index[i]] == "Buena":
        Q9A.append(7.5)
    elif music_df.Q30_1[music_index[i]] == "Regular":
        Q9A.append(5)
    elif music_df.Q30_1[music_index[i]] == "Mala":
        Q9A.append(2.5)
    else:
        Q9A.append(0)
    
    if music_df.Q30_2[music_index[i]] == "Muy buena":
        Q10A.append(10)
    elif music_df.Q30_2[music_index[i]] == "Buena":
        Q10A.append(7.5)
    elif music_df.Q30_2[music_index[i]] == "Regular":
        Q10A.append(5)
    elif music_df.Q30_2[music_index[i]] == "Mala":
        Q10A.append(2.5)
    else:
        Q10A.append(0)

# %%
Q9A = np.array(Q9A)
Q10A = np.array(Q10A)
averageQ9A = np.mean(Q9A)
medianQ9A = np.median(Q9A)
averageQ10A = np.mean(Q10A)
medianQ10A = np.median(Q10A)

print("Q30_1 mean:",averageQ9A)
print("Q30_1 median:",medianQ9A)
print("Q30_2 mean:",averageQ10A)
print("Q30_2 median:",medianQ10A)
# Out:
# Q30_1 mean: 5.277777777777778
# Q30_1 median: 5.0
# Q30_2 mean: 6.944444444444445
# Q30_2 median: 7.5

# %% [markdown]
# ## Experts = Astronomer&Musician

# %%
experts_list = []
experts_index = []
experts_counter = 0
for j in range(len(data)):
    if ((data.Q21[j] == "Astronomer") and (data.Q31[j] == "Musician")):
        experts_counter += 1
        current_row = data.iloc[j]
        experts_list.append(current_row)
        experts_index.append(j)
        
print("Number of Experts:", experts_counter)
experts_df = pd.DataFrame(experts_list)
experts_df
# Out:
# Number of Experts: 3
#            Start time    Completion time      Email            Q1  \
# 34  12/21/22 10:52:52  12/21/22 11:22:08  anonymous  Sonification
# 39  12/15/22 21:13:01  12/15/22 21:14:56        ENG  Sonification
# 43  12/15/22 21:19:13  12/15/22 21:26:25        CAT  Sonification
#
#               Q2     Q3            Q4            Q5            Q6  \
# 34  Sonification  Music  Sonification  Sonification  Sonification
# 39  Sonification  Music  Sonification  Sonification         Music
# 43         Music  Music  Sonification  Sonification         Music
#
#               Q7  ...            Q36     Q37   Q38  Q39  Q40   Q41   Q42  Q43  \
# 34  Sonification  ...  Entre 45 y 54  España   7.0  9.0  7.0  10.0  10.0  5.0
# 39         Music  ...  Entre 35 y 44  España  10.0  9.0  6.0   9.0   9.0  8.0
# 43         Music  ...  Entre 35 y 44  España   7.0  8.0  3.0   7.0   6.0  7.0
#
#     Q44   Q45
# 34  3.0   5.0
# 39  9.0  10.0
# 43  8.0  10.0
#
# [3 rows x 49 columns]

# %%
averageQ38 = experts_df['Q38'].mean()
medianQ38 = experts_df['Q38'].median()
averageQ39 = experts_df['Q39'].mean()
medianQ39 = experts_df['Q39'].median()
averageQ40 = experts_df['Q40'].mean()
medianQ40 = experts_df['Q40'].median()
averageQ41 = experts_df['Q41'].mean()
medianQ41 = experts_df['Q41'].median()
averageQ42 = experts_df['Q42'].mean()
medianQ42 = experts_df['Q42'].median()
averageQ43 = experts_df['Q43'].mean()
medianQ43 = experts_df['Q43'].median()
averageQ44 = experts_df['Q44'].mean()
medianQ44 = experts_df['Q44'].median()
averageQ45 = experts_df['Q45'].mean()
medianQ45 = experts_df['Q45'].median()

print("Q38 mean:",averageQ38)
print("Q38 median:",medianQ38)
print("Q39 mean:",averageQ39)
print("Q39 median:",medianQ39)
print("Q40 mean:",averageQ40)
print("Q40 median:",medianQ40)
print("Q41 mean:",averageQ41)
print("Q41 median:",medianQ41)
print("Q42 mean:",averageQ42)
print("Q42 median:",medianQ42)
print("Q43 mean:",averageQ43)
print("Q43 median:",medianQ43)
print("Q44 mean:",averageQ44)
print("Q44 median:",medianQ44)
print("Q45 mean:",averageQ45)
print("Q45 median:",medianQ45)
# Out:
# Q38 mean: 8.0
# Q38 median: 7.0
# Q39 mean: 8.666666666666666
# Q39 median: 9.0
# Q40 mean: 5.333333333333333
# Q40 median: 6.0
# Q41 mean: 8.666666666666666
# Q41 median: 9.0
# Q42 mean: 8.333333333333334
# Q42 median: 9.0
# Q43 mean: 6.666666666666667
# Q43 median: 7.0
# Q44 mean: 6.666666666666667
# Q44 median: 8.0
# Q45 mean: 8.333333333333334
# Q45 median: 10.0

# %%
Q9A = []
Q10A = []

for i in range(len(experts_df)):
    if experts_df.Q30_1[experts_index[i]] == "Muy buena":
        Q9A.append(10)
    elif experts_df.Q30_1[experts_index[i]] == "Buena":
        Q9A.append(7.5)
    elif experts_df.Q30_1[experts_index[i]] == "Regular":
        Q9A.append(5)
    elif experts_df.Q30_1[experts_index[i]] == "Mala":
        Q9A.append(2.5)
    else:
        Q9A.append(0)
    
    if experts_df.Q30_2[experts_index[i]] == "Muy buena":
        Q10A.append(10)
    elif experts_df.Q30_2[experts_index[i]] == "Buena":
        Q10A.append(7.5)
    elif experts_df.Q30_2[experts_index[i]] == "Regular":
        Q10A.append(5)
    elif experts_df.Q30_2[experts_index[i]] == "Mala":
        Q10A.append(2.5)
    else:
        Q10A.append(0)

# %%
Q9A = np.array(Q9A)
Q10A = np.array(Q10A)
averageQ9A = np.mean(Q9A)
medianQ9A = np.median(Q9A)
averageQ10A = np.mean(Q10A)
medianQ10A = np.median(Q10A)

print("Q30_1 mean:",averageQ9A)
print("Q30_1 median:",medianQ9A)
print("Q30_2 mean:",averageQ10A)
print("Q30_2 median:",medianQ10A)
# Out:
# Q30_1 mean: 8.333333333333334
# Q30_1 median: 7.5
# Q30_2 mean: 7.5
# Q30_2 median: 7.5

# %% [markdown]
# ## Non experts

# %%
nonexperts_list = []
nonexperts_index = []
nonexperts_counter = 0
for j in range(len(data)):
    if ((data.Q31[j] != "Musician") and (data.Q21[j] != "Astronomer") and (data.Email[j] != 'RESULTS')):
        nonexperts_counter += 1
        current_row = data.iloc[j]
        nonexperts_list.append(current_row)
        nonexperts_index.append(j)
        
print("Number of nonexperts:", nonexperts_counter)
nonexperts_df = pd.DataFrame(nonexperts_list)
nonexperts_df
# Out:
# Number of nonexperts: 29
#            Start time    Completion time      Email            Q1  \
# 1    12/8/22 11:29:21   12/8/22 12:11:53  anonymous  Sonification
# 2   12/11/22 16:39:30  12/11/22 17:06:42  anonymous  Sonification
# 3   12/11/22 18:13:31  12/11/22 18:30:53  anonymous  Sonification
# 4   12/11/22 18:28:52  12/11/22 18:44:49  anonymous  Sonification
# 5   12/11/22 18:36:17  12/11/22 19:10:36  anonymous         Music
# 8   12/11/22 21:11:36  12/11/22 21:57:40  anonymous         Music
# 9   12/11/22 21:49:45  12/11/22 23:08:49  anonymous         Music
# 10  12/12/22 10:19:49  12/12/22 10:32:16  anonymous  Sonification
# 11  12/12/22 15:59:40  12/12/22 16:34:36  anonymous         Music
# 12  12/12/22 17:10:04  12/12/22 17:33:43  anonymous  Sonification
# 13  12/12/22 17:43:05  12/12/22 17:58:08  anonymous  Sonification
# 14  12/12/22 19:14:27  12/12/22 19:18:47  anonymous         Music
# 15  12/12/22 19:40:37  12/12/22 20:03:08  anonymous  Sonification
# ...

# %%
averageQ38 = nonexperts_df['Q38'].mean()
medianQ38 = nonexperts_df['Q38'].median()
averageQ39 = nonexperts_df['Q39'].mean()
medianQ39 = nonexperts_df['Q39'].median()
averageQ40 = nonexperts_df['Q40'].mean()
medianQ40 = nonexperts_df['Q40'].median()
averageQ41 = nonexperts_df['Q41'].mean()
medianQ41 = nonexperts_df['Q41'].median()
averageQ42 = nonexperts_df['Q42'].mean()
medianQ42 = nonexperts_df['Q42'].median()
averageQ43 = nonexperts_df['Q43'].mean()
medianQ43 = nonexperts_df['Q43'].median()
averageQ44 = nonexperts_df['Q44'].mean()
medianQ44 = nonexperts_df['Q44'].median()
averageQ45 = nonexperts_df['Q45'].mean()
medianQ45 = nonexperts_df['Q45'].median()

print("Q38 mean:",averageQ38)
print("Q38 median:",medianQ38)
print("Q39 mean:",averageQ39)
print("Q39 median:",medianQ39)
print("Q40 mean:",averageQ40)
print("Q40 median:",medianQ40)
print("Q41 mean:",averageQ41)
print("Q41 median:",medianQ41)
print("Q42 mean:",averageQ42)
print("Q42 median:",medianQ42)
print("Q43 mean:",averageQ43)
print("Q43 median:",medianQ43)
print("Q44 mean:",averageQ44)
print("Q44 median:",medianQ44)
print("Q45 mean:",averageQ45)
print("Q45 median:",medianQ45)
# Out:
# Q38 mean: 4.689655172413793
# Q38 median: 4.0
# Q39 mean: 6.758620689655173
# Q39 median: 7.0
# Q40 mean: 6.344827586206897
# Q40 median: 7.0
# Q41 mean: 6.9655172413793105
# Q41 median: 7.0
# Q42 mean: 7.586206896551724
# Q42 median: 8.0
# Q43 mean: 6.448275862068965
# Q43 median: 6.0
# Q44 mean: 6.344827586206897
# Q44 median: 6.0
# Q45 mean: 6.0
# Q45 median: 6.0

# %%
Q9A = []
Q10A = []

for i in range(len(nonexperts_df)):
    if nonexperts_df.Q30_1[nonexperts_index[i]] == "Muy buena":
        Q9A.append(10)
    elif nonexperts_df.Q30_1[nonexperts_index[i]] == "Buena":
        Q9A.append(7.5)
    elif nonexperts_df.Q30_1[nonexperts_index[i]] == "Regular":
        Q9A.append(5)
    elif nonexperts_df.Q30_1[nonexperts_index[i]] == "Mala":
        Q9A.append(2.5)
    else:
        Q9A.append(0)
    
    if nonexperts_df.Q30_2[nonexperts_index[i]] == "Muy buena":
        Q10A.append(10)
    elif nonexperts_df.Q30_2[nonexperts_index[i]] == "Buena":
        Q10A.append(7.5)
    elif nonexperts_df.Q30_2[nonexperts_index[i]] == "Regular":
        Q10A.append(5)
    elif nonexperts_df.Q30_2[nonexperts_index[i]] == "Mala":
        Q10A.append(2.5)
    else:
        Q10A.append(0)

# %%
Q9A = np.array(Q9A)
Q10A = np.array(Q10A)
averageQ9A = np.mean(Q9A)
medianQ9A = np.median(Q9A)
averageQ10A = np.mean(Q10A)
medianQ10A = np.median(Q10A)

print("Q30_1 mean:",averageQ9A)
print("Q30_1 median:",medianQ9A)
print("Q30_2 mean:",averageQ10A)
print("Q30_2 median:",medianQ10A)
# Out:
# Q30_1 mean: 5.775862068965517
# Q30_1 median: 5.0
# Q30_2 mean: 6.293103448275862
# Q30_2 median: 7.5
